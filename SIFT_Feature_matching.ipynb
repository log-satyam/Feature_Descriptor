# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('J2.jpeg')
img2 = cv2.imread('J1.jpg')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
figure, ax = plt.subplots(1, 2, figsize=(16, 8))
ax[0].imshow(img, cmap='gray')
ax[1].imshow(img2, cmap='gray')

# %%
sift = cv2.xfeatures2d.SIFT_create()
kp1, desc_1 = sift.detectAndCompute(img,None)
kp2, desc_2 = sift.detectAndCompute(img2,None)
len(kp1), len(kp2)
# Out:
# (138, 804)

# %%
bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
matches = bf.match(desc_1,desc_2)
matches = sorted(matches, key = lambda x:x.distance)
img3 = cv2.drawMatches(img, kp1, img2, kp2, matches[:50], img2, flags=2)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x20a87b8abd0>, None)
