# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('J1.jpg')
img2 = img.copy()
training_img = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
sift = cv2.xfeatures2d.SIFT_create()
kp1,dsc1 = sift.detectAndCompute(img2,None)

# %%
i1 = cv2.drawKeypoints(gray,kp1,img2)
plt.imshow(i1)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
